# %%
import requests
import json
with open('token.txt', 'r') as file:
    authorization_token = file.read().strip()

url = 'https://www.strava.com/api/v3/athlete/activities?per_page=30'
headers = {
    'accept': 'application/json',
    'authorization': f'Bearer {authorization_token}'
}

response = requests.get(url, headers=headers)


data = response.json()
pretty_data = json.dumps(data, indent=4)


print(pretty_data)
# Out:
# [
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "Corrida vespertina",
#         "distance": 2015.0,
#         "moving_time": 732,
#         "elapsed_time": 1061,
#         "total_elevation_gain": 16.8,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 10021373326,
#         "start_date": "2023-10-11T19:45:09Z",
#         "start_date_local": "2023-10-11T16:45:09Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 0,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a10021373326",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 2.753,
#         "max_speed": 4.194,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 213.0,
#         "elev_low": 201.5,
#         "upload_id": 10737619023,
#         "upload_id_str": "10737619023",
#         "external_id": "5517e30e-199e-4556-9fb7-6dd653f99e95-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 0,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     },
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "solto depois de 1 semana de cativeiro na ufersa",
#         "distance": 2038.4,
#         "moving_time": 740,
#         "elapsed_time": 968,
#         "total_elevation_gain": 17.1,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 10008868899,
#         "start_date": "2023-10-09T20:44:51Z",
#         "start_date_local": "2023-10-09T17:44:51Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 0,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a10008868899",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 2.755,
#         "max_speed": 4.214,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 213.1,
#         "elev_low": 201.6,
#         "upload_id": 10724673164,
#         "upload_id_str": "10724673164",
#         "external_id": "3d328072-98fb-4d03-8182-b7761e98db0e-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 0,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     },
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "Corrida matinal",
#         "distance": 2005.8,
#         "moving_time": 757,
#         "elapsed_time": 1068,
#         "total_elevation_gain": 11.2,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 9954920924,
#         "start_date": "2023-10-01T09:54:52Z",
#         "start_date_local": "2023-10-01T06:54:52Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 0,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a9954920924",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 2.65,
#         "max_speed": 3.742,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 213.3,
#         "elev_low": 193.5,
#         "upload_id": 10668230228,
#         "upload_id_str": "10668230228",
#         "external_id": "1878a4bf-9543-44b6-9ecb-1244afbfe430-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 0,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     },
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "Corrida vespertina",
#         "distance": 2385.8,
#         "moving_time": 900,
#         "elapsed_time": 1004,
#         "total_elevation_gain": 14.3,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 9939632067,
#         "start_date": "2023-09-28T20:41:41Z",
#         "start_date_local": "2023-09-28T17:41:41Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 0,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a9939632067",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 2.651,
#         "max_speed": 3.554,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 214.2,
#         "elev_low": 192.4,
#         "upload_id": 10652258390,
#         "upload_id_str": "10652258390",
#         "external_id": "d0657ad3-ae0c-4ded-84ec-0f81fcebc3c7-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 0,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     },
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "Corrida vespertina",
#         "distance": 2501.3,
#         "moving_time": 918,
#         "elapsed_time": 1118,
#         "total_elevation_gain": 16.2,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 9920125004,
#         "start_date": "2023-09-25T20:48:50Z",
#         "start_date_local": "2023-09-25T17:48:50Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 0,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a9920125004",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 2.725,
#         "max_speed": 3.964,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 218.4,
#         "elev_low": 201.6,
#         "upload_id": 10631844309,
#         "upload_id_str": "10631844309",
#         "external_id": "701eb045-e686-4819-8ab0-af116af0bcf1-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 0,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     },
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "no tranco \ud83d\udd28",
#         "distance": 2710.4,
#         "moving_time": 969,
#         "elapsed_time": 1299,
#         "total_elevation_gain": 26.6,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 9914381271,
#         "start_date": "2023-09-24T20:41:57Z",
#         "start_date_local": "2023-09-24T17:41:57Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 0,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a9914381271",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 2.797,
#         "max_speed": 5.543,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 220.9,
#         "elev_low": 201.6,
#         "upload_id": 10625796492,
#         "upload_id_str": "10625796492",
#         "external_id": "ef2e2425-4e6a-4fe2-a202-fecd32cd1de4-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 0,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     },
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "treino 100% miado",
#         "distance": 1568.2,
#         "moving_time": 613,
#         "elapsed_time": 882,
#         "total_elevation_gain": 13.3,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 9870314558,
#         "start_date": "2023-09-17T20:32:35Z",
#         "start_date_local": "2023-09-17T17:32:35Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 0,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a9870314558",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 2.558,
#         "max_speed": 3.39,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 213.3,
#         "elev_low": 201.6,
#         "upload_id": 10579604622,
#         "upload_id_str": "10579604622",
#         "external_id": "f64196ae-839e-4af0-9350-0b671ab62e4b-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 0,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     },
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "Corrida vespertina",
#         "distance": 2008.4,
#         "moving_time": 715,
#         "elapsed_time": 863,
#         "total_elevation_gain": 10.5,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 9863115645,
#         "start_date": "2023-09-16T20:43:41Z",
#         "start_date_local": "2023-09-16T17:43:41Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 3,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a9863115645",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 2.809,
#         "max_speed": 5.588,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 220.5,
#         "elev_low": 209.2,
#         "upload_id": 10572030858,
#         "upload_id_str": "10572030858",
#         "external_id": "9fb1163e-358e-4d6e-b6ad-1cf283bfd05f-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 1,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     },
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "Corrida vespertina",
#         "distance": 2333.2,
#         "moving_time": 828,
#         "elapsed_time": 1309,
#         "total_elevation_gain": 17.2,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 9843763004,
#         "start_date": "2023-09-13T19:49:43Z",
#         "start_date_local": "2023-09-13T16:49:43Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 0,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a9843763004",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 2.818,
#         "max_speed": 5.851,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 219.3,
#         "elev_low": 201.6,
#         "upload_id": 10551748092,
#         "upload_id_str": "10551748092",
#         "external_id": "4afe1cb3-ed4e-40f4-a0e6-fd1eb009cd54-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 0,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     },
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "isso n eh esporte de gente normal nao",
#         "distance": 2307.0,
#         "moving_time": 857,
#         "elapsed_time": 962,
#         "total_elevation_gain": 14.3,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 9824670995,
#         "start_date": "2023-09-10T20:42:23Z",
#         "start_date_local": "2023-09-10T17:42:23Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 1,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a9824670995",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 2.692,
#         "max_speed": 4.16,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 214.2,
#         "elev_low": 193.5,
#         "upload_id": 10531691660,
#         "upload_id_str": "10531691660",
#         "external_id": "51aaf982-5a0f-4a9e-8536-c949b2e99f53-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 0,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     },
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "Corrida vespertina",
#         "distance": 2032.2,
#         "moving_time": 754,
#         "elapsed_time": 754,
#         "total_elevation_gain": 6.1,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 9810486948,
#         "start_date": "2023-09-08T20:48:00Z",
#         "start_date_local": "2023-09-08T17:48:00Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 1,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a9810486948",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 2.695,
#         "max_speed": 3.76,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 214.2,
#         "elev_low": 192.8,
#         "upload_id": 10516719852,
#         "upload_id_str": "10516719852",
#         "external_id": "010b208c-0991-4095-9b6f-949d682125af-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 1,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     },
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "Corrida vespertina",
#         "distance": 2008.5,
#         "moving_time": 762,
#         "elapsed_time": 762,
#         "total_elevation_gain": 4.4,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 9791193467,
#         "start_date": "2023-09-05T20:50:28Z",
#         "start_date_local": "2023-09-05T17:50:28Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 1,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a9791193467",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 2.636,
#         "max_speed": 4.14,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 214.2,
#         "elev_low": 192.8,
#         "upload_id": 10496429991,
#         "upload_id_str": "10496429991",
#         "external_id": "bef62f59-eb92-42f5-b515-1db81caa52ef-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 1,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     },
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "se num for demais \u00e9 pouco",
#         "distance": 2002.0,
#         "moving_time": 702,
#         "elapsed_time": 1160,
#         "total_elevation_gain": 3.5,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 9778285853,
#         "start_date": "2023-09-03T20:50:23Z",
#         "start_date_local": "2023-09-03T17:50:23Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 0,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a9778285853",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 2.852,
#         "max_speed": 6.018,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 213.3,
#         "elev_low": 192.1,
#         "upload_id": 10482824973,
#         "upload_id_str": "10482824973",
#         "external_id": "e92d207d-5176-480e-826e-e0097bd506dd-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 0,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     },
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "not a good day",
#         "distance": 1511.6,
#         "moving_time": 552,
#         "elapsed_time": 664,
#         "total_elevation_gain": 12.2,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 9754328078,
#         "start_date": "2023-08-31T08:22:47Z",
#         "start_date_local": "2023-08-31T05:22:47Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 0,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a9754328078",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 2.738,
#         "max_speed": 3.82,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 220.2,
#         "elev_low": 209.2,
#         "upload_id": 10457410705,
#         "upload_id_str": "10457410705",
#         "external_id": "27a48031-9051-4405-8f5c-1d4558d7ff1d-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 0,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     },
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "Corrida vespertina",
#         "distance": 2010.3,
#         "moving_time": 749,
#         "elapsed_time": 1381,
#         "total_elevation_gain": 10.9,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 9733491667,
#         "start_date": "2023-08-27T20:53:41Z",
#         "start_date_local": "2023-08-27T17:53:41Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 0,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a9733491667",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 2.684,
#         "max_speed": 5.222,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 213.5,
#         "elev_low": 192.1,
#         "upload_id": 10435321594,
#         "upload_id_str": "10435321594",
#         "external_id": "440942bf-bb62-46b4-ac2e-ce2160a99b04-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 0,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     },
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "Corrida ao entardecer",
#         "distance": 2006.0,
#         "moving_time": 669,
#         "elapsed_time": 1053,
#         "total_elevation_gain": 3.3,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 9726856373,
#         "start_date": "2023-08-26T21:05:39Z",
#         "start_date_local": "2023-08-26T18:05:39Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 0,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a9726856373",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 2.999,
#         "max_speed": 10.48,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 213.1,
#         "elev_low": 192.1,
#         "upload_id": 10428268969,
#         "upload_id_str": "10428268969",
#         "external_id": "f9806c62-cbca-4928-84ea-24d9668b8d7a-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 0,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     },
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "pegando leve",
#         "distance": 2022.4,
#         "moving_time": 768,
#         "elapsed_time": 973,
#         "total_elevation_gain": 5.5,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 9714561979,
#         "start_date": "2023-08-24T20:42:05Z",
#         "start_date_local": "2023-08-24T17:42:05Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 0,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a9714561979",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 2.633,
#         "max_speed": 5.952,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 213.6,
#         "elev_low": 192.1,
#         "upload_id": 10415261232,
#         "upload_id_str": "10415261232",
#         "external_id": "51509eab-e910-4398-9add-add6c8863a4a-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 0,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     },
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "Corrida vespertina",
#         "distance": 2013.3,
#         "moving_time": 687,
#         "elapsed_time": 828,
#         "total_elevation_gain": 5.4,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 9688490131,
#         "start_date": "2023-08-20T20:49:57Z",
#         "start_date_local": "2023-08-20T17:49:57Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 1,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a9688490131",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 2.931,
#         "max_speed": 4.683,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 213.5,
#         "elev_low": 192.1,
#         "upload_id": 10387561777,
#         "upload_id_str": "10387561777",
#         "external_id": "dbf16b44-7c8c-46d2-9073-be5eb1953766-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 0,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     },
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "Corrida vespertina",
#         "distance": 2002.3,
#         "moving_time": 671,
#         "elapsed_time": 981,
#         "total_elevation_gain": 3.2,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 9668828027,
#         "start_date": "2023-08-17T20:37:06Z",
#         "start_date_local": "2023-08-17T17:37:06Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 1,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a9668828027",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 2.984,
#         "max_speed": 5.256,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 213.1,
#         "elev_low": 192.1,
#         "upload_id": 10366307111,
#         "upload_id_str": "10366307111",
#         "external_id": "fdd709b6-5ca7-4974-8805-1ed52bca4c6e-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 1,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     },
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "Corrida vespertina",
#         "distance": 2019.2,
#         "moving_time": 739,
#         "elapsed_time": 939,
#         "total_elevation_gain": 3.3,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 9642257285,
#         "start_date": "2023-08-13T20:51:57Z",
#         "start_date_local": "2023-08-13T17:51:57Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 0,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a9642257285",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 2.732,
#         "max_speed": 3.606,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 213.1,
#         "elev_low": 192.1,
#         "upload_id": 10338367348,
#         "upload_id_str": "10338367348",
#         "external_id": "3fc02bb7-a696-4051-8e6d-360dfa8cecd7-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 0,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     },
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "sextou ",
#         "distance": 2029.0,
#         "moving_time": 728,
#         "elapsed_time": 1069,
#         "total_elevation_gain": 2.9,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 9628806396,
#         "start_date": "2023-08-11T20:40:53Z",
#         "start_date_local": "2023-08-11T17:40:53Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 0,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a9628806396",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 2.787,
#         "max_speed": 4.054,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 213.1,
#         "elev_low": 192.5,
#         "upload_id": 10324158296,
#         "upload_id_str": "10324158296",
#         "external_id": "36fb63eb-5117-4853-b432-6b784a7c5e99-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 0,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     },
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "\ud83c\udf07",
#         "distance": 2016.1,
#         "moving_time": 678,
#         "elapsed_time": 939,
#         "total_elevation_gain": 4.3,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 9577861141,
#         "start_date": "2023-08-03T20:38:09Z",
#         "start_date_local": "2023-08-03T17:38:09Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 1,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a9577861141",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 2.974,
#         "max_speed": 5.683,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 214.2,
#         "elev_low": 192.1,
#         "upload_id": 10270323408,
#         "upload_id_str": "10270323408",
#         "external_id": "f70871a4-bc4b-463f-86a5-99d52fca22e8-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 0,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     },
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "esqueci o strava desligado um temp\u00e3o vsf",
#         "distance": 1797.0,
#         "moving_time": 627,
#         "elapsed_time": 1126,
#         "total_elevation_gain": 6.1,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 9552685227,
#         "start_date": "2023-07-30T20:50:20Z",
#         "start_date_local": "2023-07-30T17:50:20Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 1,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a9552685227",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 2.866,
#         "max_speed": 4.988,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 214.2,
#         "elev_low": 192.1,
#         "upload_id": 10243634844,
#         "upload_id_str": "10243634844",
#         "external_id": "99481401-7b64-46d3-a970-87cd112f7f72-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 0,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     },
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "tem dia q o tr\u00e2nsito pauferrense ta contra mim mas eu sou mais ligeiro ",
#         "distance": 2035.4,
#         "moving_time": 657,
#         "elapsed_time": 993,
#         "total_elevation_gain": 4.1,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 9533851919,
#         "start_date": "2023-07-27T20:23:14Z",
#         "start_date_local": "2023-07-27T17:23:14Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 0,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a9533851919",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 3.098,
#         "max_speed": 7.5,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 214.2,
#         "elev_low": 192.5,
#         "upload_id": 10223749332,
#         "upload_id_str": "10223749332",
#         "external_id": "8826a620-537e-43aa-a883-68031f724f72-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 0,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     },
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "tirando a ufersa da mente",
#         "distance": 2039.0,
#         "moving_time": 779,
#         "elapsed_time": 1143,
#         "total_elevation_gain": 10.5,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 9527661994,
#         "start_date": "2023-07-26T20:12:52Z",
#         "start_date_local": "2023-07-26T17:12:52Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 1,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a9527661994",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 2.617,
#         "max_speed": 3.677,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 220.4,
#         "elev_low": 202.8,
#         "upload_id": 10217234967,
#         "upload_id_str": "10217234967",
#         "external_id": "5ae32681-3268-41ad-a6e2-335507d71660-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 0,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     },
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "Corrida vespertina",
#         "distance": 2012.2,
#         "moving_time": 734,
#         "elapsed_time": 984,
#         "total_elevation_gain": 10.7,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 9509098434,
#         "start_date": "2023-07-23T20:43:36Z",
#         "start_date_local": "2023-07-23T17:43:36Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 2,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a9509098434",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 2.741,
#         "max_speed": 4.064,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 214.2,
#         "elev_low": 192.1,
#         "upload_id": 10197708227,
#         "upload_id_str": "10197708227",
#         "external_id": "9f81875a-60da-43d1-807b-b5d2f3a9218d-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 0,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     },
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "da-lhe bem no meio",
#         "distance": 2024.1,
#         "moving_time": 726,
#         "elapsed_time": 1044,
#         "total_elevation_gain": 12.4,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 9464743637,
#         "start_date": "2023-07-16T20:34:43Z",
#         "start_date_local": "2023-07-16T17:34:43Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 0,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a9464743637",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 2.788,
#         "max_speed": 4.356,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 214.3,
#         "elev_low": 200.8,
#         "upload_id": 10150795886,
#         "upload_id_str": "10150795886",
#         "external_id": "ac2f3ea3-9532-4ac2-ab40-bf7633149329-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 0,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     },
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "tipo no driver eu mantenho a dist\u00e2ncia ",
#         "distance": 2081.2,
#         "moving_time": 816,
#         "elapsed_time": 1071,
#         "total_elevation_gain": 12.8,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 9458135890,
#         "start_date": "2023-07-15T20:38:05Z",
#         "start_date_local": "2023-07-15T17:38:05Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 1,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a9458135890",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 2.55,
#         "max_speed": 3.97,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 213.9,
#         "elev_low": 202.6,
#         "upload_id": 10143736344,
#         "upload_id_str": "10143736344",
#         "external_id": "6c05336d-39c5-45c0-b48b-4f3bcbb45e24-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 0,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     },
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "Corrida matinal",
#         "distance": 2004.5,
#         "moving_time": 756,
#         "elapsed_time": 1044,
#         "total_elevation_gain": 19.2,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 9448297466,
#         "start_date": "2023-07-14T08:30:04Z",
#         "start_date_local": "2023-07-14T05:30:04Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 0,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a9448297466",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 2.651,
#         "max_speed": 4.342,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 214.9,
#         "elev_low": 202.6,
#         "upload_id": 10133342087,
#         "upload_id_str": "10133342087",
#         "external_id": "1597db31-cbb2-4ba2-9c05-69ffbda4e3be-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 0,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     },
#     {
#         "resource_state": 2,
#         "athlete": {
#             "id": 111750247,
#             "resource_state": 1
#         },
#         "name": "i liked it better when my car had sound",
#         "distance": 2060.3,
#         "moving_time": 745,
#         "elapsed_time": 1010,
#         "total_elevation_gain": 12.8,
#         "type": "Run",
#         "sport_type": "Run",
#         "workout_type": 0,
#         "id": 9402013575,
#         "start_date": "2023-07-06T20:24:44Z",
#         "start_date_local": "2023-07-06T17:24:44Z",
#         "timezone": "(GMT-03:00) America/Fortaleza",
#         "utc_offset": -10800.0,
#         "location_city": null,
#         "location_state": null,
#         "location_country": null,
#         "achievement_count": 1,
#         "kudos_count": 0,
#         "comment_count": 0,
#         "athlete_count": 1,
#         "photo_count": 0,
#         "map": {
#             "id": "a9402013575",
#             "summary_polyline": "",
#             "resource_state": 2
#         },
#         "trainer": false,
#         "commute": false,
#         "manual": false,
#         "private": false,
#         "visibility": "followers_only",
#         "flagged": false,
#         "gear_id": null,
#         "start_latlng": [],
#         "end_latlng": [],
#         "average_speed": 2.766,
#         "max_speed": 4.158,
#         "has_heartrate": false,
#         "heartrate_opt_out": false,
#         "display_hide_heartrate_option": false,
#         "elev_high": 220.5,
#         "elev_low": 202.6,
#         "upload_id": 10084499047,
#         "upload_id_str": "10084499047",
#         "external_id": "1b17acae-b2a3-441b-9c88-3bf13eebb67c-activity.fit",
#         "from_accepted_tag": false,
#         "pr_count": 1,
#         "total_photo_count": 0,
#         "has_kudoed": false
#     }
# ]

# %%
import pandas as pd

df = pd.DataFrame(data)
df.columns
# Out:
# Index(['resource_state', 'athlete', 'name', 'distance', 'moving_time',
#        'elapsed_time', 'total_elevation_gain', 'type', 'sport_type',
#        'workout_type', 'id', 'start_date', 'start_date_local', 'timezone',
#        'utc_offset', 'location_city', 'location_state', 'location_country',
#        'achievement_count', 'kudos_count', 'comment_count', 'athlete_count',
#        'photo_count', 'map', 'trainer', 'commute', 'manual', 'private',
#        'visibility', 'flagged', 'gear_id', 'start_latlng', 'end_latlng',
#        'average_speed', 'max_speed', 'has_heartrate', 'heartrate_opt_out',
#        'display_hide_heartrate_option', 'elev_high', 'elev_low', 'upload_id',
#        'upload_id_str', 'external_id', 'from_accepted_tag', 'pr_count',
#        'total_photo_count', 'has_kudoed'],
#       dtype='object')

# %%
#Dropping some columns
columns_to_drop = ['athlete_count', 'workout_type', 'athlete', 'resource_state', 'type','kudos_count', 'comment_count', 'has_kudoed', 'total_photo_count', 'from_accepted_tag', 'external_id', 'upload_id_str', 'display_hide_heartrate_option',
'heartrate_opt_out', 'has_heartrate', 'end_latlng', 'start_latlng', 'gear_id', 'flagged', 'visibility', 'manual', 'private', 'trainer', 'commute', 'map', 'photo_count', 'upload_id'                 
]
df = df.drop(columns=columns_to_drop)

# %%
df.columns
df['start_date_local'] = pd.to_datetime(df['start_date_local'])

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource
from bokeh.layouts import gridplot

# Create a ColumnDataSource
source = ColumnDataSource(data=dict(distance=df['distance'], elevation_gain=df['total_elevation_gain']))

# Create a figure
p1 = figure(title="Elevation Gain vs. Distance", x_axis_label='Distance (in meters)', y_axis_label='Elevation Gain (in meters)')

# Add a circle glyph
p1.circle('distance', 'elevation_gain', source=source, size=8, color='blue', alpha=0.5)

# Create a ColumnDataSource
source = ColumnDataSource(data=dict(elev_high=df['elev_high'], avg_speed=df['average_speed']))

# Create a figure
p2 = figure(title="Average Speed vs. Elevation High", x_axis_label='Elevation High (in meters)', y_axis_label='Average Speed (in m/s)')

# Add a circle glyph
p2.circle('elev_high', 'avg_speed', source=source, size=8, color='red', alpha=0.5)

# Create a ColumnDataSource
source = ColumnDataSource(data=dict(max_speed=df['max_speed'], elevation_gain=df['total_elevation_gain']))

# Create a figure
p3 = figure(title="Max Speed vs. Total Elevation Gain", x_axis_label='Max Speed (in m/s)', y_axis_label='Elevation Gain (in meters)')

# Add a circle glyph
p3.circle('max_speed', 'elevation_gain', source=source, size=8, color='purple', alpha=0.5)

from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource

# Extract hour and minute of day
df['hour'] = df['start_date_local'].dt.hour
df['minute'] = df['start_date_local'].dt.minute

# Round minutes to the nearest 30
df['minute'] = df['minute'].apply(lambda x: 30 if x >= 30 else 0)

# Combine hour and minute to get time in 30-minute intervals
df['time_30min'] = df['hour'] + df['minute']/60

# Group by time in 30-minute intervals and calculate average distance
avg_distance_30min = df.groupby('time_30min')['distance'].mean().reset_index()

# Create a ColumnDataSource
source = ColumnDataSource(data=dict(time_30min=avg_distance_30min['time_30min'], distance=avg_distance_30min['distance']))

# Create a figure
p4 = figure(title="Time of Day vs. Average Distance", x_axis_label='Time of Day (in 30-minute intervals)', y_axis_label='Average Distance (in meters)')

# Add a circle glyph
p4.circle('time_30min', 'distance', source=source, size=8, color='green', alpha=0.5)

p5 = figure(title="Average Speed Distribution", x_axis_label="Average Speed (m/s)", y_axis_label="Frequency", height=450)

p5.quad(top=np.histogram(df['average_speed'], bins=20)[0], bottom=0, left=np.histogram(df['average_speed'], bins=20)[1][:-1], 
         right=np.histogram(df['average_speed'], bins=20)[1][1:], line_color="white", alpha=0.7)

p6 = figure(title="Distance vs. Average Speed", x_axis_label="Distance (meters)", y_axis_label="Average Speed (m/s)", height=450)

p6.circle(df['distance'], df['average_speed'], size=8, color='blue', alpha=0.5)


# Show the plot
output_notebook()
grid = gridplot([[p1, p2, p3], [p4, p5,p6]], width=600, height=600)
show(grid)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c6ebe1d1-0b04-410d-827a-3599d62ddccc">Loading BokehJS ...</span>
#     </div>
#   <div id="bfbc4e16-4792-4e00-b4a1-4654519c4bc0" data-root-id="p4025" style="display: contents;"></div>
